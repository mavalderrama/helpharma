# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
import unicodedata
def rem_accents(text):
    return unicodedata.normalize('NFD', text)\
           .encode('ascii', 'ignore')\
           .decode("utf-8")

# %%
consulta = pd.read_excel("Consulta.xlsx")
consulta.head()
# Out:
#         ID Fecha Consulta Sexo Paciente Fecha nacimiento  Edad actual  \
# 0  3437728     2018-05-09             F       1990-11-15           29
# 1  1965149     2018-05-15             M       1965-10-06           54
# 2  1347761     2018-05-15             M       1971-07-04           48
# 3  1840410     2018-05-15             M       1956-06-09           63
# 4   691337     2018-05-15             M       1948-11-12           71
#
#    Edad paciente consulta EPS Paciente    Diagnóstico_principal  \
# 0                    27.0     Sura EPS   L408 / Otras Psoriasis
# 1                    52.0     Sura EPS  L400 / Psoriasis Vulgar
# 2                    46.0     Sura EPS  L400 / Psoriasis Vulgar
# 3                    61.0     Sura EPS  L400 / Psoriasis Vulgar
# 4                    69.0     Sura EPS  L400 / Psoriasis Vulgar
#
#   Todos_Diagnósticos  Finalidad  ...  \
# 0               L408  No Aplica  ...
# 1          L400|L405  No Aplica  ...
# 2               L400  No Aplica  ...
# 3               L400  No Aplica  ...
# 4          L400|L405  No Aplica  ...
#
#                                         Antecedentes  \
# 0  INFECCIONES Y HOSPITALIZACIÓN: La paciente ref...
# 1  HTA toma HCTZ, enalapril 20 mg al dia ac folic...
# 2                                                neg
# 3                                                neg
# 4  HTA losartan 50 amlodipino 5 mg dia PROSTATECT...
#
#                                        Examen físico  \
# 0  Peso: 64 kg; Talla; 162 Pulso: 70 latidos/minu...
# 1  Mediciones: Peso : 91 Kg - Talla : 171 cm - IM...
# 2  Mediciones: Sistólica : 120 mmHg - Diastólica ...
# 3  Mediciones: Talla : 164 cm - Peso : 66 Kg - IM...
# 4  Mediciones: Peso : 80 Kg - Talla : 170 cm - IM...
#
#                                         Opinión plan  \
# 0  Paciente de 27 años asma, rinitis, psoriasis, ...
# 1  cita en 2 meses tiene formulacion por 3 meses ...
# 2  junta medica para aumento de dosis o cambio de...
# 3                                     continua igual
# 4  mipres vence 2 meses continua igual cita en 3 ...
#
#            Medicamentoque trae paciente  \
# 0  fexofenadina 180 mg y desonida crema
# 1  enalapril metotrexate hctz ac folico
# 2                                    no
# 3                                    no
# 4            losartan amlodipino embrel
#
#                           Examenes que trae paciente Notas aclaratorias  \
# 0  reportados en HC alergología: 03/05/2018 piel ...                NaN
# 1                                                 no                NaN
# 2  12 mayo 2018 ag sup hep b neg hep c neg hlg no...                NaN
# 3  mayo 10 2018 bun 15.8 creatinina 0.97 ast 16 a...                NaN
# 4                  hace 2 meses ultimos paraclinicos                NaN
#
#   Duración Consulta Estado Consulta Sedes Modalidad de atención
# 0          00:26:50       terminada   NaN            Presencial
# 1          00:29:08       terminada   NaN            Presencial
# 2          00:21:49       terminada   NaN            Presencial
# 3          00:22:12       terminada   NaN            Presencial
# 4          00:22:40       terminada   NaN            Presencial
#
# [5 rows x 25 columns]

# %%
columns = consulta.columns
new_columns = {}
for i in columns:
    new_columns[i] = rem_accents(i).lower().replace(" ","_").replace(".","")
columns = np.delete(columns, [1])
columns = np.delete(columns, [2])
columns
# Out:
# Index(['ID', 'Sexo Paciente', 'Edad actual', 'Edad paciente consulta',
#        'EPS Paciente', 'Diagnóstico_principal', 'Todos_Diagnósticos',
#        'Finalidad', 'Causa externa', 'Observación Dx', 'Motivo consulta',
#        'Enfermedad actual', 'Revisión sistemas', 'Antecedentes',
#        'Examen físico', 'Opinión plan', 'Medicamentoque trae paciente',
#        'Examenes que trae paciente', 'Notas aclaratorias', 'Duración Consulta',
#        'Estado Consulta', 'Sedes', 'Modalidad de atención'],
#       dtype='object')

# %%
columns = consulta.columns
new_columns = {}
for i in columns:
    new_columns[i] = rem_accents(i).lower().replace(" ","_")

for i in columns:
    consulta[i] = consulta[i].apply(lambda x: rem_accents(str(x).lower()))
    
consulta.rename(columns=new_columns, inplace=True)
consulta.head()

# %%
for i in columns:
    consulta[i] = consulta[i].apply(lambda x: rem_accents(str(x).lower()))
consulta["Fecha Consulta"] = pd.to_datetime(consulta["Fecha Consulta"])
consulta["Fecha nacimiento"] = pd.to_datetime(consulta["Fecha nacimiento"])

# %%
consulta.rename(columns=new_columns, inplace=True)
consulta.head()
# Out:
#         id fecha_consulta sexo_paciente fecha_nacimiento edad_actual  \
# 0  3437728     2018-05-09             f       1990-11-15          29
# 1  1965149     2018-05-15             m       1965-10-06          54
# 2  1347761     2018-05-15             m       1971-07-04          48
# 3  1840410     2018-05-15             m       1956-06-09          63
# 4   691337     2018-05-15             m       1948-11-12          71
#
#   edad_paciente_consulta eps_paciente    diagnostico_principal  \
# 0                   27.0     sura eps   l408 / otras psoriasis
# 1                   52.0     sura eps  l400 / psoriasis vulgar
# 2                   46.0     sura eps  l400 / psoriasis vulgar
# 3                   61.0     sura eps  l400 / psoriasis vulgar
# 4                   69.0     sura eps  l400 / psoriasis vulgar
#
#   todos_diagnosticos  finalidad  ...  \
# 0               l408  no aplica  ...
# 1          l400|l405  no aplica  ...
# 2               l400  no aplica  ...
# 3               l400  no aplica  ...
# 4          l400|l405  no aplica  ...
#
#                                         antecedentes  \
# 0  infecciones y hospitalizacion: la paciente ref...
# 1  hta toma hctz, enalapril 20 mg al dia ac folic...
# 2                                                neg
# 3                                                neg
# 4  hta losartan 50 amlodipino 5 mg dia prostatect...
#
#                                        examen_fisico  \
# 0  peso: 64 kg; talla; 162 pulso: 70 latidos/minu...
# 1  mediciones: peso : 91 kg - talla : 171 cm - im...
# 2  mediciones: sistolica : 120 mmhg - diastolica ...
# 3  mediciones: talla : 164 cm - peso : 66 kg - im...
# 4  mediciones: peso : 80 kg - talla : 170 cm - im...
#
#                                         opinion_plan  \
# 0  paciente de 27 anos asma, rinitis, psoriasis, ...
# 1  cita en 2 meses tiene formulacion por 3 meses ...
# 2  junta medica para aumento de dosis o cambio de...
# 3                                     continua igual
# 4  mipres vence 2 meses continua igual cita en 3 ...
#
#            medicamentoque_trae_paciente  \
# 0  fexofenadina 180 mg y desonida crema
# 1  enalapril metotrexate hctz ac folico
# 2                                    no
# 3                                    no
# 4            losartan amlodipino embrel
#
#                           examenes_que_trae_paciente notas_aclaratorias  \
# 0  reportados en hc alergologia: 03/05/2018 piel ...                nan
# 1                                                 no                nan
# 2  12 mayo 2018 ag sup hep b neg hep c neg hlg no...                nan
# 3  mayo 10 2018 bun 15.8 creatinina 0.97 ast 16 a...                nan
# 4                  hace 2 meses ultimos paraclinicos                nan
#
#   duracion_consulta estado_consulta sedes modalidad_de_atencion
# 0          00:26:50       terminada   nan            presencial
# 1          00:29:08       terminada   nan            presencial
# 2          00:21:49       terminada   nan            presencial
# 3          00:22:12       terminada   nan            presencial
# 4          00:22:40       terminada   nan            presencial
#
# [5 rows x 25 columns]

# %%
# consulta['diagnostico_principal'] = consulta['diagnostico_principal'].apply(lambda x: re.findall(r"[a-z][0-9]{3}", x)[0])
# consulta.head()

# %%
import nltk
def find_talla(sentence):
    words = re.sub(r"[;:-]|cms|cm", "", sentence.lower())
    words = nltk.word_tokenize(words)
    df = pd.DataFrame(nltk.pos_tag(words),columns=["token","type"])
    index = df[df["token"].isin(["talla"])].index
    if len(index) > 0 and df.loc[index[0]+1,"type"] == "CD":
        try:
            value = float(df.loc[index[0]+1,"token"])
            if value < 3:
                value *= 100
        except:
            value = np.nan
        
        return value
    else:
        return np.nan
    
def find_peso(sentence):
    words = re.sub(r"[;:-]|kg|kgs", "", sentence.lower())
    words = nltk.word_tokenize(words)
    df = pd.DataFrame(nltk.pos_tag(words),columns=["token","type"])
    index = df[df["token"].isin(["peso"])].index
    if len(index) > 0 and df.loc[index[0]+1,"type"] == "CD":
        try:
            value = float(df.loc[index[0]+1,"token"])
        except:
            value = np.nan
        
        return value
    else:
        return np.nan

# %%
consulta["talla"] = consulta["examen_fisico"].apply(find_talla)
consulta["peso"] = consulta["examen_fisico"].apply(find_peso)

# %%
consulta["imc"] = round(consulta["peso"] / ((consulta["talla"]/100)**2),1)
consulta.drop(["talla","peso"],inplace=True,axis=1)

# %%
consulta.head(10)
# Out:
#         id fecha_consulta sexo_paciente fecha_nacimiento edad_actual  \
# 0  3437728     2018-05-09             f       1990-11-15          29
# 1  1965149     2018-05-15             m       1965-10-06          54
# 2  1347761     2018-05-15             m       1971-07-04          48
# 3  1840410     2018-05-15             m       1956-06-09          63
# 4   691337     2018-05-15             m       1948-11-12          71
# 5  2435608     2018-05-16             m       1985-09-18          34
# 6  2924666     2018-05-16             m       1952-01-21          68
# 7  1027449     2018-05-16             m       1952-05-08          68
# 8  1463234     2018-05-16             m       1951-06-25          68
# 9  2709795     2018-05-16             m       1973-01-29          47
#
#   edad_paciente_consulta eps_paciente  \
# 0                   27.0     sura eps
# 1                   52.0     sura eps
# 2                   46.0     sura eps
# 3                   61.0     sura eps
# 4                   69.0     sura eps
# 5                   32.0     sura eps
# 6                    5.0     sura eps
# 7                   66.0     sura eps
# 8                   66.0     sura eps
# 9                   63.0     sura eps
#
#                                diagnostico_principal  \
# 0                             l408 / otras psoriasis
# 1                            l400 / psoriasis vulgar
# 2                            l400 / psoriasis vulgar
# 3                            l400 / psoriasis vulgar
# 4                            l400 / psoriasis vulgar
# 5                            l400 / psoriasis vulgar
# 6                            l400 / psoriasis vulgar
# 7      m073 / otras artropatias psoriasicas (l40.5?)
# 8  l405 / artropatia psoriasica (m07.0*-m07.3*, m...
# 9                            l400 / psoriasis vulgar
#
#                              todos_diagnosticos  finalidad  ...  \
# 0                                          l408  no aplica  ...
# 1                                     l400|l405  no aplica  ...
# 2                                          l400  no aplica  ...
# 3                                          l400  no aplica  ...
# 4                                     l400|l405  no aplica  ...
# 5                                     l400|l600  no aplica  ...
# 6                           l400|e780|n189|l990  no aplica  ...
# 7  m073|l570|e780|i238|i110|m541|i10x|k579|g473  no aplica  ...
# 8                                     l405|i10x  no aplica  ...
# 9                                          l400  no aplica  ...
#
#                                        examen_fisico  \
# 0  peso: 64 kg; talla; 162 pulso: 70 latidos/minu...
# 1  mediciones: peso : 91 kg - talla : 171 cm - im...
# 2  mediciones: sistolica : 120 mmhg - diastolica ...
# 3  mediciones: talla : 164 cm - peso : 66 kg - im...
# 4  mediciones: peso : 80 kg - talla : 170 cm - im...
# 5  mediciones: peso : 108 kg - talla : 170 cm - i...
# 6  mediciones: peso : 61 kg - talla : 157 cm - im...
# 7  mediciones: peso : 73 kg - talla : 158 cm - sm...
# 8  mediciones: peso : 73 kg - talla : 168 cm - im...
# 9  mediciones: peso : 76.7 kg - talla : 180 cm - ...
#
#                                         opinion_plan  \
# 0  paciente de 27 anos asma, rinitis, psoriasis, ...
# 1  cita en 2 meses tiene formulacion por 3 meses ...
# 2  junta medica para aumento de dosis o cambio de...
# 3                                     continua igual
# 4  mipres vence 2 meses continua igual cita en 3 ...
# 5  paciente de 32 anos con antecedente de higado ...
# 6  paciente de 66 anos, con 33 anos de evolucion ...
# 7  1. valoracion por oftalmologia (paciente con s...
# 8  tiene ya ordenado y pendiente por realizar per...
# 9  se hace mipres del medicamento 201805161320061...
#
#                         medicamentoque_trae_paciente  \
# 0               fexofenadina 180 mg y desonida crema
# 1               enalapril metotrexate hctz ac folico
# 2                                                 no
# 3                                                 no
# 4                         losartan amlodipino embrel
# 5    losartan , lovastatina , amlodipino, loratadina
# 6                                                nan
# 7  medicamentos: acido folico, pregabalina , dulo...
# 8  enalapril 5mg dia, espironolactoma 100 mg dia ...
# 9                  ustekinumab 45 mg sc cada 3 meses
#
#                           examenes_que_trae_paciente  \
# 0  reportados en hc alergologia: 03/05/2018 piel ...
# 1                                                 no
# 2  12 mayo 2018 ag sup hep b neg hep c neg hlg no...
# 3  mayo 10 2018 bun 15.8 creatinina 0.97 ast 16 a...
# 4                  hace 2 meses ultimos paraclinicos
# 5  presenta en el momento escaso compromiso con p...
# 6                                                nan
# 7  segun historia clinica tiene fr y anti ccp neg...
# 8  9/03/2018 na 143 k4.37 calcio 1.217 ag prostat...
# 9  ppd 0mm 04/08/2017 cada ano lo repiten al pare...
#
#                                   notas_aclaratorias duracion_consulta  \
# 0                                                nan          00:26:50
# 1                                                nan          00:29:08
# 2                                                nan          00:21:49
# 3                                                nan          00:22:12
# 4                                                nan          00:22:40
# 5                                                nan          01:00:28
# 6  16/5/2018 10:26 am lina maria colmenares rolda...          01:05:11
# 7  16/5/2018 6:37 pm lina maria colmenares roldan...          01:12:08
# 8                                                nan          00:33:23
# 9                                                nan          00:34:05
#
#   estado_consulta sedes modalidad_de_atencion   imc
# 0       terminada   nan            presencial  24.4
# 1       terminada   nan            presencial  31.1
# 2       terminada   nan            presencial  29.4
# 3       terminada   nan            presencial  24.5
# 4       terminada   nan            presencial  27.7
# 5       terminada   nan            presencial  37.4
# 6       terminada   nan            presencial  24.7
# 7       terminada   nan            presencial  29.2
# 8       terminada   nan            presencial  25.9
# 9       terminada   nan            presencial  23.7
#
# [10 rows x 26 columns]

# %%
consulta['ano']=consulta['fecha_consulta'].dt.year
consulta['mes']=consulta['fecha_consulta'].dt.month
consulta['dia']=consulta['fecha_consulta'].dt.day
consulta.head()
# Out:
#         id fecha_consulta sexo_paciente fecha_nacimiento edad_actual  \
# 0  3437728     2018-05-09             f       1990-11-15          29
# 1  1965149     2018-05-15             m       1965-10-06          54
# 2  1347761     2018-05-15             m       1971-07-04          48
# 3  1840410     2018-05-15             m       1956-06-09          63
# 4   691337     2018-05-15             m       1948-11-12          71
#
#   edad_paciente_consulta eps_paciente    diagnostico_principal  \
# 0                   27.0     sura eps   l408 / otras psoriasis
# 1                   52.0     sura eps  l400 / psoriasis vulgar
# 2                   46.0     sura eps  l400 / psoriasis vulgar
# 3                   61.0     sura eps  l400 / psoriasis vulgar
# 4                   69.0     sura eps  l400 / psoriasis vulgar
#
#   todos_diagnosticos  finalidad  ...  \
# 0               l408  no aplica  ...
# 1          l400|l405  no aplica  ...
# 2               l400  no aplica  ...
# 3               l400  no aplica  ...
# 4          l400|l405  no aplica  ...
#
#                           examenes_que_trae_paciente notas_aclaratorias  \
# 0  reportados en hc alergologia: 03/05/2018 piel ...                nan
# 1                                                 no                nan
# 2  12 mayo 2018 ag sup hep b neg hep c neg hlg no...                nan
# 3  mayo 10 2018 bun 15.8 creatinina 0.97 ast 16 a...                nan
# 4                  hace 2 meses ultimos paraclinicos                nan
#
#   duracion_consulta estado_consulta sedes modalidad_de_atencion   imc   ano  \
# 0          00:26:50       terminada   nan            presencial  24.4  2018
# 1          00:29:08       terminada   nan            presencial  31.1  2018
# 2          00:21:49       terminada   nan            presencial  29.4  2018
# 3          00:22:12       terminada   nan            presencial  24.5  2018
# 4          00:22:40       terminada   nan            presencial  27.7  2018
#
#   mes dia
# 0   5   9
# 1   5  15
# 2   5  15
# 3   5  15
# 4   5  15
#
# [5 rows x 29 columns]

# %%
consulta["diagnostico_principal"] = consulta["diagnostico_principal"].apply(lambda x: re.findall("^[a-z0-9]+", x)[0])

# %%
consulta.columns
# Out:
# Index(['id', 'fecha_consulta', 'sexo_paciente', 'fecha_nacimiento',
#        'edad_actual', 'edad_paciente_consulta', 'eps_paciente',
#        'diagnostico_principal', 'todos_diagnosticos', 'finalidad',
#        'causa_externa', 'observacion_dx', 'motivo_consulta',
#        'enfermedad_actual', 'revision_sistemas', 'antecedentes',
#        'examen_fisico', 'opinion_plan', 'medicamentoque_trae_paciente',
#        'examenes_que_trae_paciente', 'notas_aclaratorias', 'duracion_consulta',
#        'estado_consulta', 'sedes', 'modalidad_de_atencion', 'imc', 'ano',
#        'mes', 'dia'],
#       dtype='object')

# %%
consulta = consulta.drop(["edad_actual",
               "edad_paciente_consulta", 
               "eps_paciente",
               "todos_diagnosticos",
               "finalidad",
               "causa_externa",
               "observacion_dx", 
               "motivo_consulta",
               "enfermedad_actual",
               "revision_sistemas",
               "antecedentes",
               "examen_fisico",
               "opinion_plan",
               "medicamentoque_trae_paciente",
               "examenes_que_trae_paciente",
               "notas_aclaratorias",
               "duracion_consulta",
               "estado_consulta",
               "sedes",
               "modalidad_de_atencion",
               "modalidad_de_atencion"], axis=1)

# %%
consulta
# Out:
#             id fecha_consulta sexo_paciente fecha_nacimiento  \
# 0      3437728     2018-05-09             f       1990-11-15
# 1      1965149     2018-05-15             m       1965-10-06
# 2      1347761     2018-05-15             m       1971-07-04
# 3      1840410     2018-05-15             m       1956-06-09
# 4       691337     2018-05-15             m       1948-11-12
# ...        ...            ...           ...              ...
# 21918  2471517     2020-05-29             f       2001-10-01
# 21919  2792292     2020-05-29             f       1985-01-09
# 21920  2315060     2020-05-29             f       1985-02-06
# 21921  1730226     2020-05-29             f       1982-07-28
# 21922  1356415     2020-05-30             f       1988-09-27
#
#       diagnostico_principal   imc   ano  mes  dia
# 0                      l408  24.4  2018    5    9
# 1                      l400  31.1  2018    5   15
# 2                      l400  29.4  2018    5   15
# 3                      l400  24.5  2018    5   15
# 4                      l400  27.7  2018    5   15
# ...                     ...   ...   ...  ...  ...
# 21918                  l732   NaN  2020    5   29
# 21919                  l732   NaN  2020    5   29
# 21920                  l732   NaN  2020    5   29
# 21921                  l732  33.1  2020    5   29
# 21922                  l732   NaN  2020    5   30
#
# [21923 rows x 9 columns]

# %%
consulta.to_csv("clean_consulta.csv")
