# %% [markdown]
# # helPharma Load CSV to Database

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text

#pd.options.display.max_rows = 20

# %%
# %load_ext sql
#%sql postgresql://ds4a_demo_user:am3ricas@database-3.c2t89i7anl0r.us-east-1.rds.amazonaws.com/adventuretime
#%sql postgresql://postgres:root@alejx2ex.asuscomm.com:9876/postgres
# %sql postgresql://postgres:root2010@postgres.cfj83pcaofse.us-east-1.rds.amazonaws.com/postgres

# %%
from pathlib import Path
import pandas as pd

def create_schemas():
    create_sql = ""
    copy_sql = ""
    drop_sql = ""
    folder = "./data/"
    files = Path(folder).glob("*.csv")
    for file in files:
        counter = 1
        filename = file.name.split(".")[0]
        table_name = filename.replace(" ", "_").lower()
        create_sql += f"create table if not exists { table_name } (\n" 
        df = pd.read_csv(file, sep="\t")
        for index in df.dtypes.index:
            #print(index)
            #print(df.dtypes[index])
            if df.dtypes[index] == 'int64':
                stype = "integer"
            elif df.dtypes[index] == 'object' and index.find("date") >= 0:
                stype = "timestamp"
            elif df.dtypes[index] == 'float64':
                stype = "decimal"
            elif df.dtypes[index] == "datetime64":
                stype = "decimal"
            #elif df.dtypes[index] == "boolean":
            #    stype = "boolean"            
            else:
                stype = "text"
                
            comma = "" if counter == 1 else ","
            column_name = index.replace(" ", "_").lower()
            
            create_sql += f'{comma} "{index}" {stype}\n'
            counter += 1
            
        create_sql += ");\n\n"
        
        copy_sql += f"\copy {table_name} FROM '{folder}{filename}.csv' with (format CSV, header true, delimiter E'\\t');\n\n"
        drop_sql += f"drop table { table_name };\n"

    return create_sql, copy_sql, drop_sql

create_sql, copy_sql, drop_sql = create_schemas()
print(create_sql)
print(copy_sql)
#print(drop_sql)
# Out:
# create table if not exists napsi_mm (
#  "id" integer
# , "Fecha" text
# , "Total" integer
# , "Pregunta" text
# , "1" integer
# , "2" integer
# , "3" integer
# , "4" integer
# , "5" integer
# , "6" integer
# , "7" integer
# , "8" integer
# , "9" integer
# , "10" integer
# , "Sede de atención" text
# );
#
# create table if not exists napsi (
#  "ID" integer
# , "Fecha" text
# , "Total" text
# , "Pregunta" text
# , "1" integer
# , "2" integer
# , "3" integer
# , "4" integer
# , "5" integer
# , "6" integer
# , "7" integer
# , "8" integer
# , "9" integer
# , "10" integer
# , "Sede de atención" text
# );
#
# create table if not exists seguimiento_farmacoterapeutico (
#  "ID" integer
# , "Fecha" text
# , "Riesgo" text
# , "Adherencia" text
# , "Modalidad Proxima Cita" text
# , "Pregunta" text
# , "Respuesta 1" text
# , "Problemas relacionados con el medicamento" text
# , "Tipo de Problema" text
# , "Intervención dirigida a" text
# , "Estado de la intervencion" text
# ...

# %%
# %sql drop table  terapias_clean_df;
# Out:
#  * postgresql://postgres:***@postgres.cfj83pcaofse.us-east-1.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
# create table if not exists terapias_clean_df (
#  "id" integer
# , "fecha" text
# , "fecha_final" text
# , "dia" integer
# , "mes" integer
# , "ano" integer
# , "diaf" decimal
# , "mesf" decimal
# , "anof" decimal
# , "medicamento_acido_folico" integer
# , "medicamento_acido_folico/mometasona" integer
# , "medicamento_acido_retinoico" integer
# , "medicamento_acido_salicilico/betametasona" integer
# , "medicamento_acido_salicilico/mometasona" integer
# , "medicamento_acitretin" integer
# , "medicamento_adalimumab" integer
# , "medicamento_alquitran_de_hulla" integer
# , "medicamento_anticonceptivos" integer
# , "medicamento_bemerin" integer
# , "medicamento_betametasona" integer
# , "medicamento_calcipotriol" integer
# , "medicamento_calcipotriol+esteroide" integer
# , "medicamento_cefalexina" integer
# , "medicamento_certolizumab" integer
# , "medicamento_cetirizina" integer
# , "medicamento_ciclopirox" integer
# , "medicamento_ciclosporina" integer
# , "medicamento_clindamicina" integer
# , "medicamento_clindamicina/rifampicina" integer
# , "medicamento_clobetazol" integer
# , "medicamento_clorfeniramina" integer
# , "medicamento_clotrimazol" integer
# , "medicamento_dapsona" integer
# , "medicamento_deflazacort" integer
# , "medicamento_dermacortine" integer
# , "medicamento_dermovate" integer
# , "medicamento_desonida" integer
# , "medicamento_dicloxacilina" integer
# , "medicamento_difenhidramina" integer
# , "medicamento_diprosalic" integer
# , "medicamento_doxiciclina" integer
# , "medicamento_eritromicina" integer
# , "medicamento_espironolactona" integer
# , "medicamento_etanercept" integer
# , "medicamento_etoricoxib" integer
# , "medicamento_fototerapia_uv_a" integer
# , "medicamento_fototerapia_uv_b" integer
# , "medicamento_fototerapia_uva_1" integer
# , "medicamento_golimumab" integer
# , "medicamento_guselkumab" integer
# , "medicamento_hidrocortizona" integer
# , "medicamento_infiltraciones" integer
# , "medicamento_infliximab" integer
# , "medicamento_isoniazida" integer
# , "medicamento_isotretinoina" integer
# , "medicamento_ixekinumab" integer
# , "medicamento_ketoconazol" integer
# , "medicamento_leflunomida" integer
# , "medicamento_metotrexate" integer
# , "medicamento_mometasona" integer
# , "medicamento_mupirocina" integer
# , "medicamento_piridoxina" integer
# , "medicamento_prednisolona" integer
# , "medicamento_quimiofototerapia" integer
# , "medicamento_ranitidina" integer
# , "medicamento_rifampicina" integer
# , "medicamento_secukinumab" integer
# , "medicamento_soridem" integer
# , "medicamento_sulfasalazina" integer
# , "medicamento_tacrolimus" integer
# , "medicamento_tazaroteno" integer
# , "medicamento_tetraciclina_clorhidrato" integer
# , "medicamento_tofacitinib" integer
# , "medicamento_trimetoprim/sulfametoxazol" integer
# , "medicamento_urea_granulada" integer
# , "medicamento_ustekinumab" integer
# , "medicamento_vancomicina" integer
# );
# Out:
#  * postgresql://postgres:***@postgres.cfj83pcaofse.us-east-1.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
# \copy terapias_clean_df FROM './data/terapias_clean_DF.csv' with (format CSV, header true, delimiter E'\t');
# Out:
#  * postgresql://postgres:***@postgres.cfj83pcaofse.us-east-1.rds.amazonaws.com/postgres
# 0 rows affected.
# []

# %%
# %sql drop table

# %%
# %%sql
# create table if not exists napsi_mm (
#  "id" integer
# , "Fecha" text
# , "Total" integer
# , "Pregunta" text
# , "1" integer
# , "2" integer
# , "3" integer
# , "4" integer
# , "5" integer
# , "6" integer
# , "7" integer
# , "8" integer
# , "9" integer
# , "10" integer
# , "Sede de atención" text
# );
#
# create table if not exists napsi (
#  "ID" integer
# , "Fecha" text
# , "Total" text
# , "Pregunta" text
# , "1" integer
# , "2" integer
# , "3" integer
# , "4" integer
# , "5" integer
# , "6" integer
# , "7" integer
# , "8" integer
# , "9" integer
# , "10" integer
# , "Sede de atención" text
# );
#
# create table if not exists seguimiento_farmacoterapeutico (
#  "ID" integer
# , "Fecha" text
# , "Riesgo" text
# , "Adherencia" text
# , "Modalidad Proxima Cita" text
# , "Pregunta" text
# , "Respuesta 1" text
# , "Problemas relacionados con el medicamento" text
# , "Tipo de Problema" text
# , "Intervención dirigida a" text
# , "Estado de la intervencion" text
# , "Medicamento Asociado" text
# , "Observaciones Adicionales" text
# , "Sede de atención" text
# );
#
# create table if not exists hospitalizaciones (
#  "Descripcion Regional" text
# , "Id" integer
# , "Nombre_Sucursal_Ips" text
# , "Sexo" text
# , "EDAD (Años)" integer
# , "Id Diagnostico Egreso" text
# , "Descripción diagnostico (egreso)" text
# , "Dias Uci" decimal
# , "Dias Uce" text
# , "Días de Estancia (Calculada)" text
# , "Fecha Ingreso" text
# , "Fecha Egreso" text
# );
#
# create table if not exists agendas (
#  "ID" integer
# , "Fecha nacimiento" text
# , "Sexo" text
# , "Cód. Entidad" text
# , "Nombre de la Entidad" text
# , "Fecha cita" text
# , "Jerarquía" text
# , "Nivel 2" text
# , "Estado cita" text
# , "Tipo cita" text
# , "Dias proxima cita" text
# );
#
# create table if not exists nutricion_y_dietetica (
#  "ID" integer
# , "Fecha" text
# , "Profesional" text
# , "Frecuencia cita" text
# , "Modalidad cita" text
# , "Pregunta" text
# , "Sí/No" text
# , "Sede de atención" text
# );
#
# create table if not exists resultados_generales (
#  "Fecha" text
# , "ID" integer
# , "Clinimetría" text
# , "Resultado" text
# , "Sede de atención" text
# );
#
# create table if not exists pga (
#  "ID" text
# , "Fecha" text
# , "Resultado Total" integer
# , "Pregunta" text
# , "Respuesta" decimal
# , "Sede de atención" text
# );
#
# create table if not exists bsa (
#  "ID" integer
# , "Fecha" text
# , "Resultado Total" text
# , "Pregunta" text
# , "Respuesta" decimal
# , "Sede de atención" text
# );
#
# create table if not exists psicologia (
#  "ID" integer
# , "Tipo ID" text
# , "Fecha" text
# , "Frecuencia cita" text
# , "Modalidad cita" text
# , "Pregunta" text
# , "Sí/No" text
# , "Sede de atención" text
# );
#
# create table if not exists pasi (
#  "ID" integer
# , "Fecha" text
# , "Resultado Total" text
# , "Pregunta" text
# , "Respuesta" text
# , "Sede de atención" text
# );
#
# create table if not exists consulta (
#  "ID" text
# , "Fecha Consulta" text
# , "Sexo Paciente" text
# , "Fecha nacimiento" text
# , "Edad actual" integer
# , "Edad paciente consulta" decimal
# , "EPS Paciente" text
# , "Diagnóstico_principal" text
# , "Todos_Diagnósticos" text
# , "Finalidad" text
# , "Causa externa" text
# , "Observación Dx" text
# , "Motivo consulta" text
# , "Enfermedad actual" text
# , "Revisión sistemas" text
# , "Antecedentes" text
# , "Examen físico" text
# , "Opinión plan" text
# , "Medicamentoque trae paciente" text
# , "Examenes que trae paciente" text
# , "Notas aclaratorias" text
# , "Duración Consulta" text
# , "Estado Consulta" text
# , "Sedes" text
# , "Modalidad de atención" text
# );
#
# create table if not exists terapias (
#  "ID" integer
# , "Medicamento" text
# , "Fecha Inicio" text
# , "Fecha Fin" text
# );
#
# create table if not exists calidad_de_vida_relacionada_en_salud (
#  "ID,Fecha,Total Global,Salud Fisica,Psicologica,Relaciones Interpersonales,Entorno,Pregunta,Respuesta,Sede de atención" text
# );
#
# create table if not exists urgencias (
#  "Numero_de_documento" integer
# , "Fecha_Emision" text
# , "Regional_EPS_Desc" text
# , "Codigo_Prestacion_Op" text
# , "Descripcion_Prestacion" text
# , "Codigo_Diagnostico_EPS_Op" text
# , "Diagnostico_EPS_Desc" text
# );
#
# create table if not exists riesgo_asociado (
#  "ID" integer
# , "Fecha" text
# , "Resultado Total" text
# , "Pregunta" text
# , "Respuesta" text
# , "Sede de atención" text
# );
#
# create table if not exists fenotipos (
#  "ID" integer
# , "Fecha consulta" text
# , "Fenotipo(s)" text
# );
#
# create table if not exists dlqi (
#  "ID" integer
# , "Fecha" text
# , "Resultado Total" integer
# , "Pregunta" text
# , "Respuesta" text
# , "Sede de atención" text
# );
#
# create table if not exists terapia_fisica (
#  "id" integer
# , "Tipo ID" text
# , "Fecha" text
# , "Frecuencia cita" text
# , "Modalidad cita" text
# , "Pregunta" text
# , "Sí/No" text
# , "Sede de atención" text
# );
# Out:
#  * postgresql://postgres:***@postgres.cfj83pcaofse.us-east-1.rds.amazonaws.com/postgres
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# \copy napsi_mm FROM './data/Napsi_MM.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy napsi FROM './data/Napsi.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy seguimiento_farmacoterapeutico FROM './data/Seguimiento farmacoterapeutico.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy hospitalizaciones FROM './data/Hospitalizaciones.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy agendas FROM './data/Agendas.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy nutricion_y_dietetica FROM './data/Nutricion y dietetica.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy resultados_generales FROM './data/Resultados generales.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy pga FROM './data/PGA.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy bsa FROM './data/BSA.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy psicologia FROM './data/Psicologia.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy pasi FROM './data/PASI.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy consulta FROM './data/Consulta.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy terapias FROM './data/Terapias.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy calidad_de_vida_relacionada_en_salud FROM './data/Calidad de vida relacionada en salud.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy urgencias FROM './data/Urgencias.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy riesgo_asociado FROM './data/Riesgo asociado.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy fenotipos FROM './data/Fenotipos.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy dlqi FROM './data/DLQI.csv' with (format CSV, header true, delimiter E'\t');
#
# \copy terapia_fisica FROM './data/Terapia fisica.csv' with (format CSV, header true, delimiter E'\t');
# Out:
#  * postgresql://postgres:***@postgres.cfj83pcaofse.us-east-1.rds.amazonaws.com/postgres
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ----

# %% [markdown]
# ## Fixing tables

# %%
# %sql delete from seguimiento_farmacoterapeutico;
# Out:
#  * postgresql://postgres:***@alejx2ex.asuscomm.com:9876/postgres
# 16657 rows affected.
# []

# %%
# %sql \copy seguimiento_farmacoterapeutico FROM './data/Seguimiento farmacoterapeutico.csv' with (format CSV, header true, delimiter E'\t');
# Out:
#  * postgresql://postgres:***@alejx2ex.asuscomm.com:9876/postgres
# 0 rows affected.
# []

# %%
# %sql select count(*) from seguimiento_farmacoterapeutico;
# Out:
#  * postgresql://postgres:***@alejx2ex.asuscomm.com:9876/postgres
# 1 rows affected.
# [(16657,)]
